# %%
######################################################################################################
##################################   Surface Tension Calculation #####################################
######################################################################################################
import yt
from matplotlib import rc_context
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
print(yt.__version__)
# Out:
# 3.6.1

# %%
############    modify if needed    ############################
step1 = 4000
step0 = 0
temperature = 0.
alpha0 = 4.
cs2 = 1./3.
nx = 32
ny = 32
nz = 32
#######################################################

plot_file_dir_last = "./data_droplet_alpha0_{:.2f}_size{:d}-{:d}-{:d}_V/lbm_data_shshan_alpha0_".format(alpha0,nx,ny,nz) +\
      "{:.2f}".format(alpha0) + "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz) + f"{step1:06d}"
plot_file_dir_init = "./data_droplet_alpha0_{:.2f}_size{:d}-{:d}-{:d}_V/lbm_data_shshan_alpha0_".format(alpha0,nx,ny,nz) +\
      "{:.2f}".format(alpha0) + "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz) + f"{step0:06d}"
print("load in data file:")
print(plot_file_dir_init)
print(plot_file_dir_last)
ds1 = yt.load(plot_file_dir_last)
ds0 = yt.load(plot_file_dir_init)
print(ds0.field_list)
#profile_data = ds.all_data()[("boxlib", "struct_fact_rho_rho")].to_ndarray()
profile_data0 = ds0.covering_grid(
    level=0, left_edge=ds0.domain_left_edge, dims=ds0.domain_dimensions
)
profile_data1 = ds1.covering_grid(
    level=0, left_edge=ds1.domain_left_edge, dims=ds1.domain_dimensions
)
rho_frame0 = profile_data0["boxlib", "rho"]
rho_frame1 = profile_data1["boxlib", "rho"]

rho_mean0 = np.mean(rho_frame0)
rho_mean1 = np.mean(rho_frame1)
print("{:.3e}".format(rho_mean0/rho_mean1))


print(rho_frame0)
print(rho_frame1)

'''
print("rho_mean = {:.3f} and rho_max = {:.3f}".format(rho_mean,rho_max))
rho_mean/(rho_max*(4.*np.pi/3.)*radius**3)
'''
# Out:
# load in data file:
# ./data_droplet_alpha0_4.00_size32-32-32_V/lbm_data_shshan_alpha0_4.00_xi_0.0e+00_size32-32-32/plt000000
# ./data_droplet_alpha0_4.00_size32-32-32_V/lbm_data_shshan_alpha0_4.00_xi_0.0e+00_size32-32-32/plt004000
# yt : [INFO     ] 2025-02-12 03:02:05,879 Parameters: current_time              = 4000.0
# yt : [INFO     ] 2025-02-12 03:02:05,879 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-02-12 03:02:05,880 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-02-12 03:02:05,882 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-02-12 03:02:05,913 Parameters: current_time              = 0.0
# yt : [INFO     ] 2025-02-12 03:02:05,914 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-02-12 03:02:05,916 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-02-12 03:02:05,918 Parameters: domain_right_edge         = [1. 1. 1.]
# ...

# %%
alpha0 = 4.
nx = 32
ny = 32
nz = 32

plot_file_radius = "./data_droplet_alpha0_{:.2f}_size{:d}-{:d}-{:d}_V/radius_steps_out".format(alpha0, nx, ny, nz)
with open(plot_file_radius, 'r') as file:
    # Read the entire content of the file
    content = file.read()
    
    # Split the content by the tab character '\t' to create a 1D array
    data_list = [float(x) for x in content.split('\t') if x.strip()]

data_array = np.array(data_list)
N  = data_array.size
step = np.linspace(0, N-1, N)
#print(data_array)

# Plotting the data
plt.figure(figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(step, data_array, color='b')  # Create a line plot
plt.yscale('linear')
# Add labels and title
plt.xlabel("steps")  # X-axis label
plt.ylabel("radius")  # Y-axis label
plt.title("radius ~ steps, alpha0 = {:.2f}, size = [{:d},{:d},{:d}]".format(alpha0, nx, ny, nz))  # Plot title

# Show the plot
plt.show()

# %% [markdown]
# If set $R = 0.15, 0.16$ as init value system will crush, $\rho \to 0$ droplet disappear, due to the resolution (num of grids points)?

# %%
##### modified fitting #####

R1 = 0.281392    # init 0.3
R2 = 0.383825    # init 0.4
R3 = 0.14906     # init 0.2
R4 = 0.247406    # init 0.27
R5 = 0.333154    # init 0.35


###########################    modify if needed    ############################
alpha0 = 4.
cs2 = 1./3.
r0 = [0.506432,0.506434,0.506434]       # obtained from AMReX code, center of mass 
temperature = 0.
nx = 32
ny = 32
nz = 32

frame_step = 4000
frame_step_III = 7000
###############################################################################

# load in frame file
plot_file_dir_I = "./data_droplet_alpha0_{:.2f}_size{:d}-{:d}-{:d}_I/lbm_data_shshan_alpha0_{:.2f}".format(alpha0,nx,ny,nz,alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz) + f"{frame_step:06}"
plot_file_dir_II = "./data_droplet_alpha0_{:.2f}_size{:d}-{:d}-{:d}_II/lbm_data_shshan_alpha0_{:.2f}".format(alpha0,nx,ny,nz,alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz) + f"{frame_step:06}"
plot_file_dir_III = "./data_droplet_alpha0_{:.2f}_size{:d}-{:d}-{:d}_III/lbm_data_shshan_alpha0_{:.2f}".format(alpha0,nx,ny,nz,alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz) + f"{frame_step_III:06}"
plot_file_dir_IV = "./data_droplet_alpha0_{:.2f}_size{:d}-{:d}-{:d}_IV/lbm_data_shshan_alpha0_{:.2f}".format(alpha0,nx,ny,nz,alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz) + f"{frame_step_III:06}"
plot_file_dir_V = "./data_droplet_alpha0_{:.2f}_size{:d}-{:d}-{:d}_V/lbm_data_shshan_alpha0_{:.2f}".format(alpha0,nx,ny,nz,alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz) + f"{frame_step:06}"


ds1 = yt.load(plot_file_dir_I)
ds2 = yt.load(plot_file_dir_II)
ds3 = yt.load(plot_file_dir_III)
ds4 = yt.load(plot_file_dir_IV)
ds5 = yt.load(plot_file_dir_V)

print(ds1.field_list)
profile_data_I = ds1.covering_grid(
    level=0, left_edge=ds1.domain_left_edge, dims=ds1.domain_dimensions
)
profile_data_II = ds2.covering_grid(
    level=0, left_edge=ds2.domain_left_edge, dims=ds2.domain_dimensions
)
profile_data_III = ds3.covering_grid(
    level=0, left_edge=ds3.domain_left_edge, dims=ds3.domain_dimensions
)
profile_data_IV = ds4.covering_grid(
    level=0, left_edge=ds4.domain_left_edge, dims=ds4.domain_dimensions
)
profile_data_V = ds5.covering_grid(
    level=0, left_edge=ds5.domain_left_edge, dims=ds5.domain_dimensions
)

# grid lattice length
box = ds1.domain_dimensions
L = ds1.domain_right_edge - ds1.domain_left_edge
dr = L/box
#print(dr) 

afx = profile_data_I["boxlib", "afx"]
afy = profile_data_I["boxlib", "afy"]
afz = profile_data_I["boxlib", "afz"]
agx = profile_data_I["boxlib", "agx"]
agy = profile_data_I["boxlib", "agy"]
agz = profile_data_I["boxlib", "agz"]
rho = profile_data_I["boxlib", "rho"]
phi = profile_data_I["boxlib", "phi"]
domain_size = ds1.domain_dimensions
domain_right_edge = ds1.domain_right_edge
print("acceleration field afx has shape ", afx.shape)
 
dx = domain_right_edge[0]/domain_size[0]
dy = domain_right_edge[1]/domain_size[1]
dz = domain_right_edge[2]/domain_size[2]

nc = [int(r0[0]//dx), int(r0[1]//dy), int(r0[2]//dz)]
print("center of mass grid index:", nc)
force_rho = 0.
force_phi = 0.
#for nx in range(0, domain_size[0]):
    #print("acceleration {:.8f}\tgrid index {:d}".format(ax[nx,nc[1],nc[2]], nx))
for nx in range(0, domain_size[0]//2):
    #print(rho[nx,nc[1],nc[2]])
    force_phi = force_phi + phi[nx,nc[1],nc[2]]*agx[nx,nc[1],nc[2]]*dx
    force_rho = force_rho + rho[nx,nc[1],nc[2]]*afx[nx,nc[1],nc[2]]*dx
force_rho = force_rho.value
force_phi = force_phi.value
print("fluid f force difference", force_rho)
print("fluid g force difference", force_phi)
deltaP1 = force_rho + force_phi
print("deltaP*R1 along x =", deltaP1*R1)


afx = profile_data_II["boxlib", "afx"]
afy = profile_data_II["boxlib", "afy"]
afz = profile_data_II["boxlib", "afz"]
agx = profile_data_II["boxlib", "agx"]
agy = profile_data_II["boxlib", "agy"]
agz = profile_data_II["boxlib", "agz"]
rho = profile_data_II["boxlib", "rho"]
phi = profile_data_II["boxlib", "phi"]
rhot = profile_data_II["boxlib", "p_bulk"]
domain_size = ds2.domain_dimensions

force_rho = 0.
force_phi = 0.
#for nx in range(0, domain_size[0]):
    #print("acceleration {:.8f}\tgrid index {:d}".format(ax[nx,nc[1],nc[2]], nx))
for nx in range(0, domain_size[0]//2):
    #print(rho[nx,nc[1],nc[2]])
    force_phi = force_phi + phi[nx,nc[1],nc[2]]*agx[nx,nc[1],nc[2]]*dx
    force_rho = force_rho + rho[nx,nc[1],nc[2]]*afx[nx,nc[1],nc[2]]*dx
force_rho = force_rho.value
force_phi = force_phi.value
print("fluid f force difference", force_rho)
print("fluid g force difference", force_phi)
deltaP2 = force_rho + force_phi
print("deltaP*R2 along x =", deltaP2*R2)
print("total density outside: {:.5f}, total density inside: {:.5f}".format(rhot[0,nc[1],nc[2]], rhot[nc[0],nc[1],nc[2]]))
print("(rho*cs2) P_out - P_in =", (rhot[nc[0],nc[1],nc[2]]-rhot[0,nc[1],nc[2]])*cs2)
print(deltaP2)


afx = profile_data_III["boxlib", "afx"]
afy = profile_data_III["boxlib", "afy"]
afz = profile_data_III["boxlib", "afz"]
agx = profile_data_III["boxlib", "agx"]
agy = profile_data_III["boxlib", "agy"]
agz = profile_data_III["boxlib", "agz"]
rho = profile_data_III["boxlib", "rho"]
phi = profile_data_III["boxlib", "phi"]
rhot = profile_data_III["boxlib", "p_bulk"]
domain_size = ds3.domain_dimensions

force_rho = 0.
force_phi = 0.
#for nx in range(0, domain_size[0]):
    #print("acceleration {:.8f}\tgrid index {:d}".format(ax[nx,nc[1],nc[2]], nx))
for nx in range(0, domain_size[0]//2):
    #print(rho[nx,nc[1],nc[2]])
    force_phi = force_phi + phi[nx,nc[1],nc[2]]*agx[nx,nc[1],nc[2]]*dx
    force_rho = force_rho + rho[nx,nc[1],nc[2]]*afx[nx,nc[1],nc[2]]*dx
force_rho = force_rho.value
force_phi = force_phi.value
print("fluid f force difference", force_rho)
print("fluid g force difference", force_phi)
deltaP3 = force_rho + force_phi
print("deltaP*R3 along x =", deltaP3*R3)
print("total density outside: {:.5f}, total density inside: {:.5f}".format(rhot[0,nc[1],nc[2]], rhot[nc[0],nc[1],nc[2]]))
print("P_out - P_in =", (rhot[nc[0],nc[1],nc[2]]-rhot[0,nc[1],nc[2]])*cs2)
print(deltaP3)

afx = profile_data_IV["boxlib", "afx"]
afy = profile_data_IV["boxlib", "afy"]
afz = profile_data_IV["boxlib", "afz"]
agx = profile_data_IV["boxlib", "agx"]
agy = profile_data_IV["boxlib", "agy"]
agz = profile_data_IV["boxlib", "agz"]
rho = profile_data_IV["boxlib", "rho"]
phi = profile_data_IV["boxlib", "phi"]
domain_size = ds4.domain_dimensions

force_rho = 0.
force_phi = 0.
#for nx in range(0, domain_size[0]):
    #print("acceleration {:.8f}\tgrid index {:d}".format(ax[nx,nc[1],nc[2]], nx))
for nx in range(0, domain_size[0]//2):
    #print(rho[nx,nc[1],nc[2]])
    force_phi = force_phi + phi[nx,nc[1],nc[2]]*agx[nx,nc[1],nc[2]]*dx
    force_rho = force_rho + rho[nx,nc[1],nc[2]]*afx[nx,nc[1],nc[2]]*dx
force_rho = force_rho.value
force_phi = force_phi.value
print("fluid f force difference", force_rho)
print("fluid g force difference", force_phi)
deltaP4 = force_rho + force_phi
print("deltaP*R4 along x =", deltaP4*R4)


afx = profile_data_V["boxlib", "afx"]
afy = profile_data_V["boxlib", "afy"]
afz = profile_data_V["boxlib", "afz"]
agx = profile_data_V["boxlib", "agx"]
agy = profile_data_V["boxlib", "agy"]
agz = profile_data_V["boxlib", "agz"]
rho = profile_data_V["boxlib", "rho"]
phi = profile_data_V["boxlib", "phi"]
domain_size = ds5.domain_dimensions

force_rho = 0.
force_phi = 0.
#for nx in range(0, domain_size[0]):
    #print("acceleration {:.8f}\tgrid index {:d}".format(ax[nx,nc[1],nc[2]], nx))
for nx in range(0, domain_size[0]//2):
    #print(rho[nx,nc[1],nc[2]])
    force_phi = force_phi + phi[nx,nc[1],nc[2]]*agx[nx,nc[1],nc[2]]*dx
    force_rho = force_rho + rho[nx,nc[1],nc[2]]*afx[nx,nc[1],nc[2]]*dx
force_rho = force_rho.value
force_phi = force_phi.value
print("fluid f force difference", force_rho)
print("fluid g force difference", force_phi)
deltaP5 = force_rho + force_phi
print("deltaP*R5 along x =", deltaP5*R5)
# Out:
# yt : [INFO     ] 2025-02-18 06:02:11,683 Parameters: current_time              = 4000.0
# yt : [INFO     ] 2025-02-18 06:02:11,683 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-02-18 06:02:11,684 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-02-18 06:02:11,686 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-02-18 06:02:11,715 Parameters: current_time              = 4000.0
# yt : [INFO     ] 2025-02-18 06:02:11,717 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-02-18 06:02:11,718 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-02-18 06:02:11,720 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-02-18 06:02:11,748 Parameters: current_time              = 7000.0
# yt : [INFO     ] 2025-02-18 06:02:11,749 Parameters: domain_dimensions         = [32 32 32]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

R_array = np.array([R1, R2, R3, R4, R5])
invR_array = 1./R_array  # Independent variable
deltaP_array = np.array([deltaP1, deltaP2, deltaP3, deltaP4, deltaP5])  # Dependent variable

# Compute linear regression coefficients
n = len(invR_array)
x_mean = np.mean(invR_array)
y_mean = np.mean(deltaP_array)

# Calculate slope (k) and intercept (b)
k = np.sum((invR_array - x_mean) * (deltaP_array - y_mean)) / np.sum((invR_array - x_mean) ** 2)
b = y_mean - k * x_mean

# Generate predictions
y_pred = k * invR_array + b

# Print results
print(f"Slope (k): {k}")
print(f"Intercept (b): {b}")

# Plot the data and regression line
plt.figure(figsize=(8, 6), dpi=100)  # Optional: Set the figure size
plt.scatter(invR_array, deltaP_array, color='blue', label='Data points')
plt.plot(invR_array, y_pred, color='red', label='Regression line')
plt.xlabel(r'$\frac{1}{R}$', fontsize=18)
plt.ylabel(r'$\Delta P$', fontsize=18)
# set ylim range
plt.ylim(min(deltaP_array)*0.8, max(deltaP_array)*1.2)
plt.legend()
plt.show()
# Out:
# Slope (k): 0.000263236367330302
# Intercept (b): 0.00015853373131504344
